# %%
import requests
import json

prompt ="""\
Please write me an essay about the real world applications of quantum computing.

Specifically, I would like you to write about the following topics:
- Quantum computing and machine learning
- Quantum computing and cryptography
- Quantum computing and biology
"""

url = 'https://api.superpowered.ai/v1/long_form'
payload = {
    'prompt': prompt,
    'knowledge_base_ids': ['94edf5f6-0ce6-4d21-addc-45078ddad4f7'],
    'model': 'gpt-4',
    'response_length': 'medium',
    'segment_length': 'short',
}
auth = ('server_b8a47ef7edfca853017f319dec44cad9', 'Fp3wz1LCKakgCHw7t-Pnn-BMsfV1pLdAKBiJQfVHFk8')
resp = requests.post(url, json=payload, auth=auth)

print(resp.json())
# Out:
# {'request': {'auto_query_guidance': '', 'response_length': 'medium', 'segment_length': 'short', 'temperature': 0.5, 'model': 'gpt-4-1106-preview', 'knowledge_base_ids': ['94edf5f6-0ce6-4d21-addc-45078ddad4f7'], 'prompt': 'Please write me an essay about the real world applications of quantum computing.\n\nSpecifically, I would like you to write about the following topics:\n- Quantum computing and machine learning\n- Quantum computing and cryptography\n- Quantum computing and biology\n'}, 'created_on': 1704915426, 'response': {'short_title': '', 'id': '21192e79-ec69-4e71-873e-30766ef79e1f', 'title': '', 'sections': []}, 'id': '21192e79-ec69-4e71-873e-30766ef79e1f', 'type': 'LONG_FORM', 'status': 'PENDING', 'status_url': 'https://api.superpowered.ai/v1/long_form/21192e79-ec69-4e71-873e-30766ef79e1f'}

# %%
auth = ('server_b8a47ef7edfca853017f319dec44cad9', 'Fp3wz1LCKakgCHw7t-Pnn-BMsfV1pLdAKBiJQfVHFk8')

while resp.json()['status'] not in {'COMPLETE', 'FAILED'}:
    print(resp.json()['status'])
    resp = requests.get(resp.json()['status_url'], auth=auth)
# Out:
# PENDING
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS

# %%
export_url = 'https://api.superpowered.ai/v1/long_form/21192e79-ec69-4e71-873e-30766ef79e1f/exports/audio'

payload = {
    'audio_voice_name': 'openai_alloy'
}

export_resp = requests.post(export_url, json=payload, auth=auth)
print(export_resp.json())
# Out:
# {'request': {'long_form_job_id': '21192e79-ec69-4e71-873e-30766ef79e1f', 'audio_voice_name': 'openai_alloy'}, 'expires': 1705002314, 'created_on': 1704915914, 'response': {'download_url': None, 'download_expires': 1704919514}, 'id': '839b7259-3908-48df-a00c-10c24d0eb292', 'type': 'LONG_FORM_AUDIO_EXPORT', 'status': 'PENDING', 'status_url': 'https://api.superpowered.ai/v1/jobs/839b7259-3908-48df-a00c-10c24d0eb292'}

# %%
while export_resp.json()['status'] not in {'COMPLETE', 'FAILED'}:
    export_resp = requests.get(export_resp.json()['status_url'], auth=auth)
    print(export_resp.json()['status'])

download_url = export_resp.json()
# Out:
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# IN_PROGRESS
# COMPLETE

# %%
print(export_resp.json())

print(export_resp.json()['response']['download_url'])
# Out:
# {'created_on': 1704915914, 'expires': 1705002314, 'id': '839b7259-3908-48df-a00c-10c24d0eb292', 'request': {'audio_voice_name': 'openai_alloy', 'long_form_job_id': '21192e79-ec69-4e71-873e-30766ef79e1f'}, 'response': {'download_expires': 1704919514, 'download_url': 'https://files.superpowered.ai/long_form_exports/074fef7d-39fe-4239-a333-eb696e42667a/21192e79-ec69-4e71-873e-30766ef79e1f/quantum_computing_potential_in_fields__openai_alloy.mp3?Expires=1704919800&Signature=AJbeweSU-vpMMCtMW8vc9VnkDA-pCvUrrM1RQ2RGvLBYnJ8rDj7WnH8lvzqTuyJtUXGw4AW2tfiwvCpoGPLVwT-bBPWMjxBkhA-GOLKiyDhboU-zz3lAGEFJAfv-aJztVTXFgVgPt76bxfDSMxxzaY~yk9OVhBLelXGVwcTLGd6gcqKh8JB8vjHtKN4kG9zvFFo0s0utt9Lrm2HOtZLZ1~bMijMGIwHMSsrxMe0uALFjvaRN3A8~8cl9jW5tFN9nw7itdun9uYzu5PGS5ZHQqFpAbBT6XwBcA4geyIBDDPFSHXzw01ufzCDhV8~5x6XrLmaH3qUMjMdFdbfW3Tn2iQ__&Key-Pair-Id=KN9MQLKJLYE2H'}, 'status': 'COMPLETE', 'status_url': 'https://api.superpowered.ai/v1/jobs/839b7259-3908-48df-a00c-10c24d0eb292', 'type': 'LONG_FORM_AUDIO_EXPORT'}
# https://files.superpowered.ai/long_form_exports/074fef7d-39fe-4239-a333-eb696e42667a/21192e79-ec69-4e71-873e-30766ef79e1f/quantum_computing_potential_in_fields__openai_alloy.mp3?Expires=1704919800&Signature=AJbeweSU-vpMMCtMW8vc9VnkDA-pCvUrrM1RQ2RGvLBYnJ8rDj7WnH8lvzqTuyJtUXGw4AW2tfiwvCpoGPLVwT-bBPWMjxBkhA-GOLKiyDhboU-zz3lAGEFJAfv-aJztVTXFgVgPt76bxfDSMxxzaY~yk9OVhBLelXGVwcTLGd6gcqKh8JB8vjHtKN4kG9zvFFo0s0utt9Lrm2HOtZLZ1~bMijMGIwHMSsrxMe0uALFjvaRN3A8~8cl9jW5tFN9nw7itdun9uYzu5PGS5ZHQqFpAbBT6XwBcA4geyIBDDPFSHXzw01ufzCDhV8~5x6XrLmaH3qUMjMdFdbfW3Tn2iQ__&Key-Pair-Id=KN9MQLKJLYE2H
